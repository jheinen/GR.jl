# %%
using GR
inline()
# Out:
# "svg"

# %%
x = 0:pi/100:2*pi
y = sin(x)

plot(x,y,title="sin(x)")
# Out:
# SVG(Uint8[0x3c,0x3f,0x78,0x6d,0x6c,0x20,0x76,0x65,0x72,0x73  …  0x67,0x3e,0x0a,0x3c,0x2f,0x73,0x76,0x67,0x3e,0x0a])

# %%
x = linspace(-2*pi,2*pi);
y1 = sin(x);
y2 = cos(x);

plot(x,y1,x,y2)
# Out:
# SVG(Uint8[0x3c,0x3f,0x78,0x6d,0x6c,0x20,0x76,0x65,0x72,0x73  …  0x2f,0x3e,0x0a,0x3c,0x2f,0x73,0x76,0x67,0x3e,0x0a])

# %%
Y = [16 2 3 13;5 11 10 8;9 7 6 12;4 14 15 1]

plot(Y)
# Out:
# SVG(Uint8[0x3c,0x3f,0x78,0x6d,0x6c,0x20,0x76,0x65,0x72,0x73  …  0x2f,0x3e,0x0a,0x3c,0x2f,0x73,0x76,0x67,0x3e,0x0a])

# %%
x = 0:pi/100:2*pi
y1 = sin(x)
y2 = sin(x-0.25)
y3 = sin(x-0.5)

plot(x,y1,x,y2,"--",x,y3,":")
# Out:
# SVG(Uint8[0x3c,0x3f,0x78,0x6d,0x6c,0x20,0x76,0x65,0x72,0x73  …  0x2f,0x3e,0x0a,0x3c,0x2f,0x73,0x76,0x67,0x3e,0x0a])

# %%
x = 0:pi/10:2*pi
y1 = sin(x)
y2 = sin(x-0.25)
y3 = sin(x-0.5)

plot(x,y1,"g",x,y2,"b--o",x,y3,"c*")
# Out:
# SVG(Uint8[0x3c,0x3f,0x78,0x6d,0x6c,0x20,0x76,0x65,0x72,0x73  …  0x2f,0x3e,0x0a,0x3c,0x2f,0x73,0x76,0x67,0x3e,0x0a])

# %%
x = linspace(0,10,150)
y = cos(5*x)

title("2-D Line Plot")
xlabel("x")
ylabel("cos(5x)")
plot(x,y,"b")
# Out:
# SVG(Uint8[0x3c,0x3f,0x78,0x6d,0x6c,0x20,0x76,0x65,0x72,0x73  …  0x67,0x3e,0x0a,0x3c,0x2f,0x73,0x76,0x67,0x3e,0x0a])
